# %% [markdown]
# <span style="font-size: 25px; font-weight: bold;">Matches - Result(2025)</span>

# %%
import pandas as pd
match_result = pd.read_csv("Ipl Matches (2025)/ipl_match_results.csv")

match_result.head()
# Out:
#    No  Match_No                            Team1_Team2  \
# 0   1  Match 58         Punjab Kings vs Delhi Capitals
# 1   2  Match 57             KKR vs Chennai Super Kings
# 2   3  Match 56       Mumbai Indians vs Gujarat Titans
# 3   4  Match 55  Sunrisers Hyderabad vs Delhi Capitals
# 4   5  Match 54   Punjab Kings vs Lucknow Super Giants
#
#                                          Team1_Score      Team2_Score  \
# 0  PunjabKingsPBKS122/1(10.1OV)DelhiCapitalsDC (1...              NaN
# 1                                    179/6 (20.0 OV)  183/8 (19.4 OV)
# 2                                    155/8 (20.0 OV)  147/7 (19.0 OV)
# 3  SunrisersHyderabadSRHDelhiCapitalsDC133/7(20.0OV)              NaN
# 4                                    236/5 (20.0 OV)  199/7 (20.0 OV)
#
#                                  Result                      Date  \
# 0                       Match abandoned  MAY, THU 8 , 7:30 pm IST
# 1  Chennai Super Kings Won by 2 Wickets  MAY, WED 7 , 7:30 pm IST
# 2       Gujarat Titans Won by 3 Wickets  MAY, TUE 6 , 7:30 pm IST
# 3                             No result  MAY, MON 5 , 7:30 pm IST
# 4           Punjab Kings Won by 37 Runs  MAY, SUN 4 , 7:30 pm IST
#
#                        Time  \
# 0  MAY, THU 8 , 7:30 pm IST
# 1  MAY, WED 7 , 7:30 pm IST
# 2  MAY, TUE 6 , 7:30 pm IST
# 3  MAY, MON 5 , 7:30 pm IST
# 4  MAY, SUN 4 , 7:30 pm IST
#
#                                                Venue Is_Super_Over
# 0  Himachal Pradesh Cricket Association Stadium, ...            No
# 1                              Eden Gardens, Kolkata            No
# 2                           Wankhede Stadium, Mumbai            No
# 3      Rajiv Gandhi International Stadium, Hyderabad            No
# 4  Himachal Pradesh Cricket Association Stadium, ...            No

# %%
match_result.columns = match_result.columns.str.strip()

# %%
match_result['Match_Number'] = match_result['Match_No'].str.extract(r'Match (\d+)').astype(int)
match_result = match_result.sort_values(by='Match_Number')
match_result = match_result.drop('Match_Number', axis=1).reset_index(drop=True)

print(match_result)
# Out:
#     No  Match_No                                  Team1_Team2  \
# 0   58   Match 1                                   KKR vs RCB
# 1   57   Match 2      Sunrisers Hyderabad vs Rajasthan Royals
# 2   56   Match 3        Chennai Super Kings vs Mumbai Indians
# 3   55   Match 4       Delhi Capitals vs Lucknow Super Giants
# 4   54   Match 5               Gujarat Titans vs Punjab Kings
# 5   53   Match 6                      Rajasthan Royals vs KKR
# 6   52   Match 7  Sunrisers Hyderabad vs Lucknow Super Giants
# 7   51   Match 8                   Chennai Super Kings vs RCB
# 8   50   Match 9             Gujarat Titans vs Mumbai Indians
# 9   49  Match 10        Delhi Capitals vs Sunrisers Hyderabad
# 10  48  Match 11      Rajasthan Royals vs Chennai Super Kings
# 11  47  Match 12                        Mumbai Indians vs KKR
# 12  46  Match 13         Lucknow Super Giants vs Punjab Kings
# 13  45  Match 14                        RCB vs Gujarat Titans
# 14  44  Match 15                   KKR vs Sunrisers Hyderabad
# 15  43  Match 16       Lucknow Super Giants vs Mumbai Indians
# 16  42  Match 17        Chennai Super Kings vs Delhi Capitals
# 17  41  Match 18             Punjab Kings vs Rajasthan Royals
# 18  38  Match 19                  KKR vs Lucknow Super Giants
# 19  40  Match 20        Sunrisers Hyderabad vs Gujarat Titans
# 20  39  Match 21                        Mumbai Indians vs RCB
# 21  37  Match 22          Punjab Kings vs Chennai Super Kings
# 22  36  Match 23           Gujarat Titans vs Rajasthan Royals
# 23  35  Match 24                        RCB vs Delhi Capitals
# 24  34  Match 25                   Chennai Super Kings vs KKR
# 25  33  Match 26       Lucknow Super Giants vs Gujarat Titans
# 26  32  Match 27          Sunrisers Hyderabad vs Punjab Kings
# 27  31  Match 28                      Rajasthan Royals vs RCB
# 28  30  Match 29             Delhi Capitals vs Mumbai Indians
# 29  29  Match 30  Lucknow Super Giants vs Chennai Super Kings
# 30  28  Match 31                          Punjab Kings vs KKR
# 31  27  Match 32           Delhi Capitals vs Rajasthan Royals
# 32  26  Match 33        Mumbai Indians vs Sunrisers Hyderabad
# 33  25  Match 34                          RCB vs Punjab Kings
# 34  24  Match 35             Gujarat Titans vs Delhi Capitals
# 35  23  Match 36     Rajasthan Royals vs Lucknow Super Giants
# 36  22  Match 37                          Punjab Kings vs RCB
# 37  21  Match 38        Mumbai Indians vs Chennai Super Kings
# 38  20  Match 39                        KKR vs Gujarat Titans
# 39  19  Match 40       Lucknow Super Giants vs Delhi Capitals
# 40  18  Match 41        Sunrisers Hyderabad vs Mumbai Indians
# 41  17  Match 42                      RCB vs Rajasthan Royals
# 42  16  Match 43   Chennai Super Kings vs Sunrisers Hyderabad
# 43  15  Match 44                          KKR vs Punjab Kings
# 44  14  Match 45       Mumbai Indians vs Lucknow Super Giants
# 45  13  Match 46                        Delhi Capitals vs RCB
# 46  12  Match 47           Rajasthan Royals vs Gujarat Titans
# 47  11  Match 48                        Delhi Capitals vs KKR
# 48  10  Match 49          Chennai Super Kings vs Punjab Kings
# 49   9  Match 50           Rajasthan Royals vs Mumbai Indians
# 50   8  Match 51        Gujarat Titans vs Sunrisers Hyderabad
# 51   7  Match 52                   RCB vs Chennai Super Kings
# 52   6  Match 53                      KKR vs Rajasthan Royals
# 53   5  Match 54         Punjab Kings vs Lucknow Super Giants
# 54   4  Match 55        Sunrisers Hyderabad vs Delhi Capitals
# 55   3  Match 56             Mumbai Indians vs Gujarat Titans
# 56   2  Match 57                   KKR vs Chennai Super Kings
# 57   1  Match 58               Punjab Kings vs Delhi Capitals
#
#                                           Team1_Score  \
# 0                                     174/8 (20.0 OV)
# 1                                     286/6 (20.0 OV)
# 2                                     158/6 (19.1 OV)
# 3                                     211/9 (19.3 OV)
# 4                                     232/5 (20.0 OV)
# 5                                     151/9 (20.0 OV)
# 6                                     190/9 (20.0 OV)
# 7                                     146/8 (20.0 OV)
# 8                                     196/8 (20.0 OV)
# 9                                     166/3 (16.0 OV)
# 10                                    182/9 (20.0 OV)
# 11                                    121/2 (12.5 OV)
# 12                                    171/7 (20.0 OV)
# 13                                    169/8 (20.0 OV)
# 14                                    200/6 (20.0 OV)
# 15                                    203/8 (20.0 OV)
# 16                                    158/5 (20.0 OV)
# 17                                    155/9 (20.0 OV)
# 18                                    234/7 (20.0 OV)
# 19                                    152/8 (20.0 OV)
# 20                                    209/9 (20.0 OV)
# 21                                    219/6 (20.0 OV)
# 22                                    217/6 (20.0 OV)
# 23                                    163/7 (20.0 OV)
# 24                                    103/9 (20.0 OV)
# 25                                    186/4 (19.3 OV)
# 26                                    247/2 (18.3 OV)
# 27                                    173/4 (20.0 OV)
# 28                                      193 (19.0 OV)
# 29                                    166/7 (20.0 OV)
# 30                                      111 (15.3 OV)
# 31                188/5 (20.0 OV) (Super Over: 188/5)
# 32                                    166/6 (18.1 OV)
# 33                                     95/9 (14.0 OV)
# 34                                    204/3 (19.2 OV)
# 35                                    178/5 (20.0 OV)
# 36                                    157/6 (20.0 OV)
# 37                                    177/1 (15.4 OV)
# 38                                    159/8 (20.0 OV)
# 39                                    159/6 (20.0 OV)
# 40                                    143/8 (20.0 OV)
# 41                                    205/5 (20.0 OV)
# 42                                      154 (19.5 OV)
# 43                                       7/0 (1.0 OV)
# 44                                    215/7 (20.0 OV)
# 45                                    162/8 (20.0 OV)
# 46                                    212/2 (15.5 OV)
# 47                                    190/9 (20.0 OV)
# 48                                      190 (19.2 OV)
# 49                                      117 (16.1 OV)
# 50                                    224/6 (20.0 OV)
# 51                                    213/5 (20.0 OV)
# 52                                    206/4 (20.0 OV)
# 53                                    236/5 (20.0 OV)
# 54  SunrisersHyderabadSRHDelhiCapitalsDC133/7(20.0OV)
# 55                                    155/8 (20.0 OV)
# 56                                    179/6 (20.0 OV)
# 57  PunjabKingsPBKS122/1(10.1OV)DelhiCapitalsDC (1...
#
#                             Team2_Score  \
# 0                       177/3 (16.2 OV)
# 1                       242/6 (20.0 OV)
# 2                       155/9 (20.0 OV)
# 3                       209/8 (20.0 OV)
# 4                       243/5 (20.0 OV)
# 5                       153/2 (17.3 OV)
# 6                       193/5 (16.1 OV)
# 7                       196/7 (20.0 OV)
# 8                       160/6 (20.0 OV)
# 9                         163 (18.4 OV)
# 10                      176/6 (20.0 OV)
# 11                        116 (16.2 OV)
# 12                      177/2 (16.2 OV)
# 13                      170/2 (17.5 OV)
# 14                        120 (16.4 OV)
# 15                      191/5 (20.0 OV)
# 16                      183/6 (20.0 OV)
# 17                      205/4 (20.0 OV)
# 18                      238/3 (20.0 OV)
# 19                      153/3 (16.4 OV)
# 20                      221/5 (20.0 OV)
# 21                      201/5 (20.0 OV)
# 22                        159 (19.2 OV)
# 23                      169/4 (17.5 OV)
# 24                      107/2 (10.1 OV)
# 25                      180/6 (20.0 OV)
# 26                      245/6 (20.0 OV)
# 27                      175/1 (17.3 OV)
# 28                      205/5 (20.0 OV)
# 29                      168/5 (19.3 OV)
# 30                         95 (15.1 OV)
# 31  188/4 (20.0 OV) (Super Over: 188/4)
# 32                      162/5 (20.0 OV)
# 33                       98/5 (12.1 OV)
# 34                      203/8 (20.0 OV)
# 35                      180/5 (20.0 OV)
# 36                      159/3 (18.5 OV)
# 37                      176/5 (20.0 OV)
# 38                      198/3 (20.0 OV)
# 39                      161/2 (17.5 OV)
# 40                      146/3 (15.4 OV)
# 41                      194/9 (20.0 OV)
# 42                      155/5 (18.4 OV)
# 43                      201/4 (20.0 OV)
# 44                        161 (20.0 OV)
# 45                      165/4 (18.3 OV)
# 46                      209/4 (20.0 OV)
# 47                      204/9 (20.0 OV)
# 48                      194/6 (19.4 OV)
# 49                      217/2 (20.0 OV)
# 50                      186/6 (20.0 OV)
# 51                      211/5 (20.0 OV)
# 52                      205/8 (20.0 OV)
# 53                      199/7 (20.0 OV)
# 54                                  NaN
# 55                      147/7 (19.0 OV)
# 56                      183/8 (19.4 OV)
# 57                                  NaN
#
#                                                Result  \
# 0        Royal Challengers Bengaluru Won by 7 Wickets
# 1                  Sunrisers Hyderabad Won by 44 Runs
# 2                Chennai Super Kings Won by 4 Wickets
# 3                      Delhi Capitals Won by 1 Wicket
# 4                         Punjab Kings Won by 11 Runs
# 5              Kolkata Knight Riders Won by 8 Wickets
# 6               Lucknow Super Giants Won by 5 Wickets
# 7          Royal Challengers Bengaluru Won by 50 Runs
# 8                       Gujarat Titans Won by 36 Runs
# 9                     Delhi Capitals Won by 7 Wickets
# 10                     Rajasthan Royals Won by 6 Runs
# 11                    Mumbai Indians Won by 8 Wickets
# 12                      Punjab Kings Won by 8 Wickets
# 13                    Gujarat Titans Won by 8 Wickets
# 14               Kolkata Knight Riders Won by 80 Runs
# 15                Lucknow Super Giants Won by 12 Runs
# 16                      Delhi Capitals Won by 25 Runs
# 17                    Rajasthan Royals Won by 50 Runs
# 18                 Lucknow Super Giants Won by 4 Runs
# 19                    Gujarat Titans Won by 7 Wickets
# 20         Royal Challengers Bengaluru Won by 12 Runs
# 21                        Punjab Kings Won by 18 Runs
# 22                      Gujarat Titans Won by 58 Runs
# 23                    Delhi Capitals Won by 6 Wickets
# 24             Kolkata Knight Riders Won by 8 Wickets
# 25              Lucknow Super Giants Won by 6 Wickets
# 26               Sunrisers Hyderabad Won by 8 Wickets
# 27       Royal Challengers Bengaluru Won by 9 Wickets
# 28                      Mumbai Indians Won by 12 Runs
# 29               Chennai Super Kings Won by 5 Wickets
# 30                        Punjab Kings Won by 16 Runs
# 31  Delhi Capitals won - Super over            del...
# 32                    Mumbai Indians Won by 4 Wickets
# 33                      Punjab Kings Won by 5 Wickets
# 34                    Gujarat Titans Won by 7 Wickets
# 35                 Lucknow Super Giants Won by 2 Runs
# 36       Royal Challengers Bengaluru Won by 7 Wickets
# 37                    Mumbai Indians Won by 9 Wickets
# 38                      Gujarat Titans Won by 39 Runs
# 39                    Delhi Capitals Won by 8 Wickets
# 40                    Mumbai Indians Won by 7 Wickets
# 41         Royal Challengers Bengaluru Won by 11 Runs
# 42               Sunrisers Hyderabad Won by 5 Wickets
# 43                                          No result
# 44                      Mumbai Indians Won by 54 Runs
# 45       Royal Challengers Bengaluru Won by 6 Wickets
# 46                  Rajasthan Royals Won by 8 Wickets
# 47               Kolkata Knight Riders Won by 14 Runs
# 48                      Punjab Kings Won by 4 Wickets
# 49                     Mumbai Indians Won by 100 Runs
# 50                      Gujarat Titans Won by 38 Runs
# 51          Royal Challengers Bengaluru Won by 2 Runs
# 52                          Kolkata Knight Riders won
# 53                        Punjab Kings Won by 37 Runs
# 54                                          No result
# 55                    Gujarat Titans Won by 3 Wickets
# 56               Chennai Super Kings Won by 2 Wickets
# 57                                    Match abandoned
#
#                          Date                       Time  \
# 0   MAR, SAT 22 , 7:30 pm IST  MAR, SAT 22 , 7:30 pm IST
# 1   MAR, SUN 23 , 3:30 pm IST  MAR, SUN 23 , 3:30 pm IST
# 2   MAR, SUN 23 , 7:30 pm IST  MAR, SUN 23 , 7:30 pm IST
# 3   MAR, MON 24 , 7:30 pm IST  MAR, MON 24 , 7:30 pm IST
# 4   MAR, TUE 25 , 7:30 pm IST  MAR, TUE 25 , 7:30 pm IST
# 5   MAR, WED 26 , 7:30 pm IST  MAR, WED 26 , 7:30 pm IST
# 6   MAR, THU 27 , 7:30 pm IST  MAR, THU 27 , 7:30 pm IST
# 7   MAR, FRI 28 , 7:30 pm IST  MAR, FRI 28 , 7:30 pm IST
# 8   MAR, SAT 29 , 7:30 pm IST  MAR, SAT 29 , 7:30 pm IST
# 9   MAR, SUN 30 , 3:30 pm IST  MAR, SUN 30 , 3:30 pm IST
# 10  MAR, SUN 30 , 7:30 pm IST  MAR, SUN 30 , 7:30 pm IST
# 11  MAR, MON 31 , 7:30 pm IST  MAR, MON 31 , 7:30 pm IST
# 12   APR, TUE 1 , 7:30 pm IST   APR, TUE 1 , 7:30 pm IST
# 13   APR, WED 2 , 7:30 pm IST   APR, WED 2 , 7:30 pm IST
# 14   APR, THU 3 , 7:30 pm IST   APR, THU 3 , 7:30 pm IST
# 15   APR, FRI 4 , 7:30 pm IST   APR, FRI 4 , 7:30 pm IST
# 16   APR, SAT 5 , 3:30 pm IST   APR, SAT 5 , 3:30 pm IST
# 17   APR, SAT 5 , 7:30 pm IST   APR, SAT 5 , 7:30 pm IST
# 18   APR, TUE 8 , 3:30 pm IST   APR, TUE 8 , 3:30 pm IST
# 19   APR, SUN 6 , 7:30 pm IST   APR, SUN 6 , 7:30 pm IST
# 20   APR, MON 7 , 7:30 pm IST   APR, MON 7 , 7:30 pm IST
# 21   APR, TUE 8 , 7:30 pm IST   APR, TUE 8 , 7:30 pm IST
# 22   APR, WED 9 , 7:30 pm IST   APR, WED 9 , 7:30 pm IST
# 23  APR, THU 10 , 7:30 pm IST  APR, THU 10 , 7:30 pm IST
# 24  APR, FRI 11 , 7:30 pm IST  APR, FRI 11 , 7:30 pm IST
# 25  APR, SAT 12 , 3:30 pm IST  APR, SAT 12 , 3:30 pm IST
# 26  APR, SAT 12 , 7:30 pm IST  APR, SAT 12 , 7:30 pm IST
# 27  APR, SUN 13 , 3:30 pm IST  APR, SUN 13 , 3:30 pm IST
# 28  APR, SUN 13 , 7:30 pm IST  APR, SUN 13 , 7:30 pm IST
# 29  APR, MON 14 , 7:30 pm IST  APR, MON 14 , 7:30 pm IST
# 30  APR, TUE 15 , 7:30 pm IST  APR, TUE 15 , 7:30 pm IST
# 31  APR, WED 16 , 7:30 pm IST  APR, WED 16 , 7:30 pm IST
# 32  APR, THU 17 , 7:30 pm IST  APR, THU 17 , 7:30 pm IST
# 33  APR, FRI 18 , 7:30 pm IST  APR, FRI 18 , 7:30 pm IST
# 34  APR, SAT 19 , 3:30 pm IST  APR, SAT 19 , 3:30 pm IST
# 35  APR, SAT 19 , 7:30 pm IST  APR, SAT 19 , 7:30 pm IST
# 36  APR, SUN 20 , 3:30 pm IST  APR, SUN 20 , 3:30 pm IST
# 37  APR, SUN 20 , 7:30 pm IST  APR, SUN 20 , 7:30 pm IST
# 38  APR, MON 21 , 7:30 pm IST  APR, MON 21 , 7:30 pm IST
# 39  APR, TUE 22 , 7:30 pm IST  APR, TUE 22 , 7:30 pm IST
# 40  APR, WED 23 , 7:30 pm IST  APR, WED 23 , 7:30 pm IST
# 41  APR, THU 24 , 7:30 pm IST  APR, THU 24 , 7:30 pm IST
# 42  APR, FRI 25 , 7:30 pm IST  APR, FRI 25 , 7:30 pm IST
# 43  APR, SAT 26 , 7:30 pm IST  APR, SAT 26 , 7:30 pm IST
# 44  APR, SUN 27 , 3:30 pm IST  APR, SUN 27 , 3:30 pm IST
# 45  APR, SUN 27 , 7:30 pm IST  APR, SUN 27 , 7:30 pm IST
# 46  APR, MON 28 , 7:30 pm IST  APR, MON 28 , 7:30 pm IST
# 47  APR, TUE 29 , 7:30 pm IST  APR, TUE 29 , 7:30 pm IST
# 48  APR, WED 30 , 7:30 pm IST  APR, WED 30 , 7:30 pm IST
# 49   MAY, THU 1 , 7:30 pm IST   MAY, THU 1 , 7:30 pm IST
# 50   MAY, FRI 2 , 7:30 pm IST   MAY, FRI 2 , 7:30 pm IST
# 51   MAY, SAT 3 , 7:30 pm IST   MAY, SAT 3 , 7:30 pm IST
# 52   MAY, SUN 4 , 3:30 pm IST   MAY, SUN 4 , 3:30 pm IST
# 53   MAY, SUN 4 , 7:30 pm IST   MAY, SUN 4 , 7:30 pm IST
# 54   MAY, MON 5 , 7:30 pm IST   MAY, MON 5 , 7:30 pm IST
# 55   MAY, TUE 6 , 7:30 pm IST   MAY, TUE 6 , 7:30 pm IST
# 56   MAY, WED 7 , 7:30 pm IST   MAY, WED 7 , 7:30 pm IST
# 57   MAY, THU 8 , 7:30 pm IST   MAY, THU 8 , 7:30 pm IST
#
#                                                 Venue Is_Super_Over
# 0                               Eden Gardens, Kolkata            No
# 1       Rajiv Gandhi International Stadium, Hyderabad            No
# 2                     MA Chidambaram Stadium, Chennai            No
# 3   Dr YS Rajasekhara Reddy ACA-VDCA Cricket Stadi...            No
# 4                    Narendra Modi Stadium, Ahmedabad            No
# 5                               ACA Stadium, Guwahati            No
# 6       Rajiv Gandhi International Stadium, Hyderabad            No
# 7                     MA Chidambaram Stadium, Chennai            No
# 8                    Narendra Modi Stadium, Ahmedabad            No
# 9   Dr YS Rajasekhara Reddy ACA-VDCA Cricket Stadi...            No
# 10                              ACA Stadium, Guwahati            No
# 11                           Wankhede Stadium, Mumbai            No
# 12  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...            No
# 13                   M Chinnaswamy Stadium, Bengaluru            No
# 14                              Eden Gardens, Kolkata            No
# 15  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...            No
# 16                    MA Chidambaram Stadium, Chennai            No
# 17                        New PCA Stadium, Chandigarh            No
# 18                              Eden Gardens, Kolkata            No
# 19      Rajiv Gandhi International Stadium, Hyderabad            No
# 20                           Wankhede Stadium, Mumbai            No
# 21                        New PCA Stadium, Chandigarh            No
# 22                   Narendra Modi Stadium, Ahmedabad            No
# 23                   M Chinnaswamy Stadium, Bengaluru            No
# 24                    MA Chidambaram Stadium, Chennai            No
# 25  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...            No
# 26      Rajiv Gandhi International Stadium, Hyderabad            No
# 27                     Sawai Mansingh Stadium, Jaipur            No
# 28                        Arun Jaitley Stadium, Delhi            No
# 29  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...            No
# 30                        New PCA Stadium, Chandigarh            No
# 31                        Arun Jaitley Stadium, Delhi           Yes
# 32                           Wankhede Stadium, Mumbai            No
# 33                   M Chinnaswamy Stadium, Bengaluru            No
# 34                   Narendra Modi Stadium, Ahmedabad            No
# 35                     Sawai Mansingh Stadium, Jaipur            No
# 36                        New PCA Stadium, Chandigarh            No
# 37                           Wankhede Stadium, Mumbai            No
# 38                              Eden Gardens, Kolkata            No
# 39  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...            No
# 40      Rajiv Gandhi International Stadium, Hyderabad            No
# 41                   M Chinnaswamy Stadium, Bengaluru            No
# 42                    MA Chidambaram Stadium, Chennai            No
# 43                              Eden Gardens, Kolkata            No
# 44                           Wankhede Stadium, Mumbai            No
# 45                        Arun Jaitley Stadium, Delhi            No
# 46                     Sawai Mansingh Stadium, Jaipur            No
# 47                        Arun Jaitley Stadium, Delhi            No
# 48                    MA Chidambaram Stadium, Chennai            No
# 49                     Sawai Mansingh Stadium, Jaipur            No
# 50                   Narendra Modi Stadium, Ahmedabad            No
# 51                   M Chinnaswamy Stadium, Bengaluru            No
# 52                              Eden Gardens, Kolkata            No
# 53  Himachal Pradesh Cricket Association Stadium, ...            No
# 54      Rajiv Gandhi International Stadium, Hyderabad            No
# 55                           Wankhede Stadium, Mumbai            No
# 56                              Eden Gardens, Kolkata            No
# 57  Himachal Pradesh Cricket Association Stadium, ...            No

# %%
print("Initial DataFrame shape:", match_result.shape)
print("\nColumn names:")
print(match_result.columns.tolist())
# Out:
# Initial DataFrame shape: (58, 10)
#
# Column names:
# ['No', 'Match_No', 'Team1_Team2', 'Team1_Score', 'Team2_Score', 'Result', 'Date', 'Time', 'Venue', 'Is_Super_Over']

# %% [markdown]
# <span style="font-size: 20px; font-weight: bold;">1.1 - Clean the Result Column </span>

# %%
def clean_result(result_str):
    if 'Won by' in result_str:
        return result_str
    elif 'Super over' in result_str.lower():
        return 'Delhi Capitals Won by Super Over'
    else:
        return result_str

match_result['Result'] = match_result['Result'].apply(clean_result)

print("\nCleaned Result column:")
print(match_result['Result'].head())
# Out:
# Cleaned Result column:
# 0    Royal Challengers Bengaluru Won by 7 Wickets
# 1              Sunrisers Hyderabad Won by 44 Runs
# 2            Chennai Super Kings Won by 4 Wickets
# 3                  Delhi Capitals Won by 1 Wicket
# 4                     Punjab Kings Won by 11 Runs
# Name: Result, dtype: object

# %% [markdown]
# <span style="font-size: 20px; font-weight: bold;">1.2 - Extract Winner and Winning Margin </span>

# %%
import pandas as pd


def extract_winner_margin(result):
    if "Won by" in result:
        parts = result.split("Won by")
        winner = parts[0].strip()
        margin = parts[1].strip()
    elif "won - Super over" in result or "Won - Super over" in result:
        winner = result.split("won")[0].strip().title()  # Title-case to normalize
        margin = "Super Over"
    else:
        winner = None
        margin = None
    return pd.Series([winner, margin])

match_result[['Winner', 'Winning_Margin']] = match_result['Result'].apply(extract_winner_margin)

print(match_result[['No', 'Result', 'Winner', 'Winning_Margin']])
# Out:
#     No                                             Result  \
# 0   58       Royal Challengers Bengaluru Won by 7 Wickets
# 1   57                 Sunrisers Hyderabad Won by 44 Runs
# 2   56               Chennai Super Kings Won by 4 Wickets
# 3   55                     Delhi Capitals Won by 1 Wicket
# 4   54                        Punjab Kings Won by 11 Runs
# 5   53             Kolkata Knight Riders Won by 8 Wickets
# 6   52              Lucknow Super Giants Won by 5 Wickets
# 7   51         Royal Challengers Bengaluru Won by 50 Runs
# 8   50                      Gujarat Titans Won by 36 Runs
# 9   49                    Delhi Capitals Won by 7 Wickets
# 10  48                     Rajasthan Royals Won by 6 Runs
# 11  47                    Mumbai Indians Won by 8 Wickets
# 12  46                      Punjab Kings Won by 8 Wickets
# 13  45                    Gujarat Titans Won by 8 Wickets
# 14  44               Kolkata Knight Riders Won by 80 Runs
# 15  43                Lucknow Super Giants Won by 12 Runs
# 16  42                      Delhi Capitals Won by 25 Runs
# 17  41                    Rajasthan Royals Won by 50 Runs
# 18  38                 Lucknow Super Giants Won by 4 Runs
# 19  40                    Gujarat Titans Won by 7 Wickets
# 20  39         Royal Challengers Bengaluru Won by 12 Runs
# 21  37                        Punjab Kings Won by 18 Runs
# 22  36                      Gujarat Titans Won by 58 Runs
# 23  35                    Delhi Capitals Won by 6 Wickets
# 24  34             Kolkata Knight Riders Won by 8 Wickets
# 25  33              Lucknow Super Giants Won by 6 Wickets
# 26  32               Sunrisers Hyderabad Won by 8 Wickets
# 27  31       Royal Challengers Bengaluru Won by 9 Wickets
# 28  30                      Mumbai Indians Won by 12 Runs
# 29  29               Chennai Super Kings Won by 5 Wickets
# 30  28                        Punjab Kings Won by 16 Runs
# 31  27  Delhi Capitals won - Super over            del...
# 32  26                    Mumbai Indians Won by 4 Wickets
# 33  25                      Punjab Kings Won by 5 Wickets
# 34  24                    Gujarat Titans Won by 7 Wickets
# 35  23                 Lucknow Super Giants Won by 2 Runs
# 36  22       Royal Challengers Bengaluru Won by 7 Wickets
# 37  21                    Mumbai Indians Won by 9 Wickets
# 38  20                      Gujarat Titans Won by 39 Runs
# 39  19                    Delhi Capitals Won by 8 Wickets
# 40  18                    Mumbai Indians Won by 7 Wickets
# 41  17         Royal Challengers Bengaluru Won by 11 Runs
# 42  16               Sunrisers Hyderabad Won by 5 Wickets
# 43  15                                          No result
# 44  14                      Mumbai Indians Won by 54 Runs
# 45  13       Royal Challengers Bengaluru Won by 6 Wickets
# 46  12                  Rajasthan Royals Won by 8 Wickets
# 47  11               Kolkata Knight Riders Won by 14 Runs
# 48  10                      Punjab Kings Won by 4 Wickets
# 49   9                     Mumbai Indians Won by 100 Runs
# 50   8                      Gujarat Titans Won by 38 Runs
# 51   7          Royal Challengers Bengaluru Won by 2 Runs
# 52   6                          Kolkata Knight Riders won
# 53   5                        Punjab Kings Won by 37 Runs
# 54   4                                          No result
# 55   3                    Gujarat Titans Won by 3 Wickets
# 56   2               Chennai Super Kings Won by 2 Wickets
# 57   1                                    Match abandoned
#
#                          Winner Winning_Margin
# 0   Royal Challengers Bengaluru      7 Wickets
# 1           Sunrisers Hyderabad        44 Runs
# 2           Chennai Super Kings      4 Wickets
# 3                Delhi Capitals       1 Wicket
# 4                  Punjab Kings        11 Runs
# 5         Kolkata Knight Riders      8 Wickets
# 6          Lucknow Super Giants      5 Wickets
# 7   Royal Challengers Bengaluru        50 Runs
# 8                Gujarat Titans        36 Runs
# 9                Delhi Capitals      7 Wickets
# 10             Rajasthan Royals         6 Runs
# 11               Mumbai Indians      8 Wickets
# 12                 Punjab Kings      8 Wickets
# 13               Gujarat Titans      8 Wickets
# 14        Kolkata Knight Riders        80 Runs
# 15         Lucknow Super Giants        12 Runs
# 16               Delhi Capitals        25 Runs
# 17             Rajasthan Royals        50 Runs
# 18         Lucknow Super Giants         4 Runs
# 19               Gujarat Titans      7 Wickets
# 20  Royal Challengers Bengaluru        12 Runs
# 21                 Punjab Kings        18 Runs
# 22               Gujarat Titans        58 Runs
# 23               Delhi Capitals      6 Wickets
# 24        Kolkata Knight Riders      8 Wickets
# 25         Lucknow Super Giants      6 Wickets
# 26          Sunrisers Hyderabad      8 Wickets
# 27  Royal Challengers Bengaluru      9 Wickets
# 28               Mumbai Indians        12 Runs
# 29          Chennai Super Kings      5 Wickets
# 30                 Punjab Kings        16 Runs
# 31               Delhi Capitals     Super Over
# 32               Mumbai Indians      4 Wickets
# 33                 Punjab Kings      5 Wickets
# 34               Gujarat Titans      7 Wickets
# 35         Lucknow Super Giants         2 Runs
# 36  Royal Challengers Bengaluru      7 Wickets
# 37               Mumbai Indians      9 Wickets
# 38               Gujarat Titans        39 Runs
# 39               Delhi Capitals      8 Wickets
# 40               Mumbai Indians      7 Wickets
# 41  Royal Challengers Bengaluru        11 Runs
# 42          Sunrisers Hyderabad      5 Wickets
# 43                         None           None
# 44               Mumbai Indians        54 Runs
# 45  Royal Challengers Bengaluru      6 Wickets
# 46             Rajasthan Royals      8 Wickets
# 47        Kolkata Knight Riders        14 Runs
# 48                 Punjab Kings      4 Wickets
# 49               Mumbai Indians       100 Runs
# 50               Gujarat Titans        38 Runs
# 51  Royal Challengers Bengaluru         2 Runs
# 52                         None           None
# 53                 Punjab Kings        37 Runs
# 54                         None           None
# 55               Gujarat Titans      3 Wickets
# 56          Chennai Super Kings      2 Wickets
# 57                         None           None

# %% [markdown]
# <span style="font-size: 20px; font-weight: bold;">1.3 - Extract Team1 and Team2 names separately </span>

# %%
def extract_teams(team_str):
    if ' vs ' in team_str:
        return team_str.split(' vs ')
    return None, None

match_result[['Team1', 'Team2']] = pd.DataFrame(match_result['Team1_Team2'].apply(extract_teams).tolist(), index=match_result.index)

print("\nSeparated team columns:")
print(match_result[['Team1', 'Team2']].head())
# Out:
# Separated team columns:
#                  Team1                 Team2
# 0                  KKR                   RCB
# 1  Sunrisers Hyderabad      Rajasthan Royals
# 2  Chennai Super Kings        Mumbai Indians
# 3       Delhi Capitals  Lucknow Super Giants
# 4       Gujarat Titans          Punjab Kings

# %% [markdown]
# <span style="font-size: 20px; font-weight: bold;">1.4 - Clean Date Column </span>

# %%
import re
from datetime import datetime

def clean_date(date_str):

    date_match = re.search(r'([A-Z]{3}, [A-Z]{3} \d{1,2})', date_str)
    if date_match:
        date_part = date_match.group(1)

        date_with_year = date_part + ', 2025'

        try:
            return datetime.strptime(date_with_year, '%b, %a %d, %Y')
        except ValueError:
            return None
    return None

match_result['Date'] = match_result['Date'].apply(clean_date)

# Check the cleaned dates
print("\nCleaned date column:")
print(match_result['Date'].head())
# Out:
# Cleaned date column:
# 0   2025-03-22
# 1   2025-03-23
# 2   2025-03-23
# 3   2025-03-24
# 4   2025-03-25
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# <span style="font-size: 20px; font-weight: bold;">1.5 - Clean Time Column </span>

# %%
import re
from datetime import datetime

def clean_time(time_str):
    time_match = re.search(r'(\d{1,2}:\d{2}\s*[AP]M)', time_str, re.IGNORECASE)
    
    if time_match:
        time_part = time_match.group(1).upper().strip()
        try:
            return datetime.strptime(time_part, '%I:%M %p').time()
        except ValueError:
            return None
    
    return None

# Apply it to your DataFrame
match_result['Time'] = match_result['Time'].apply(clean_time)

# Optional: Check cleaned times
print("\nCleaned time column:")
print(match_result['Time'].head())
# Out:
# Cleaned time column:
# 0    19:30:00
# 1    15:30:00
# 2    19:30:00
# 3    19:30:00
# 4    19:30:00
# Name: Time, dtype: object

# %% [markdown]
# <span style="font-size: 20px; font-weight: bold;">1.6 - Extract Score Details for Team 1 </span>

# %%
def extract_score(score_str):
    
    if isinstance(score_str, str):
       
        runs_match = re.search(r'(\d+)(?:/\d+)?', score_str)
        runs = int(runs_match.group(1)) if runs_match else None
        
        wickets_match = re.search(r'/(\d+)', score_str)
        wickets = int(wickets_match.group(1)) if wickets_match else 10 if runs is not None else None
        
        
        overs_match = re.search(r'\((\d+\.\d+|\d+) OV\)', score_str)
        overs = float(overs_match.group(1)) if overs_match else None
        
        return runs, wickets, overs
    return None, None, None


match_result['Team1_Runs'], match_result['Team1_Wickets'], match_result['Team1_Overs'] = zip(*match_result['Team1_Score'].apply(extract_score))

print("\nTeam1 score details:")
print(match_result[['Team1_Runs', 'Team1_Wickets', 'Team1_Overs']].head())
# Out:
# Team1 score details:
#    Team1_Runs  Team1_Wickets  Team1_Overs
# 0         174              8         20.0
# 1         286              6         20.0
# 2         158              6         19.1
# 3         211              9         19.3
# 4         232              5         20.0

# %% [markdown]
# <span style="font-size: 20px; font-weight: bold;">1.7 - Extract Score Details for Team 2 </span>

# %%
# Apply to Team2 Score
match_result['Team2_Runs'], match_result['Team2_Wickets'], match_result['Team2_Overs'] = zip(*match_result['Team2_Score'].apply(extract_score))

# Check Team2 score details
print("\nTeam2 score details:")
print(match_result[['Team2_Runs', 'Team2_Wickets', 'Team2_Overs']].head())
# Out:
# Team2 score details:
#    Team2_Runs  Team2_Wickets  Team2_Overs
# 0       177.0            3.0         16.2
# 1       242.0            6.0         20.0
# 2       155.0            9.0         20.0
# 3       209.0            8.0         20.0
# 4       243.0            5.0         20.0

# %% [markdown]
# <span style="font-size: 20px; font-weight: bold;">1.8 - Clean Venue and Super Over Information </span>

# %%
def clean_venue(venue_str):
    if isinstance(venue_str, str):
        return venue_str.strip()
    return None

match_result['Venue'] = match_result['Venue'].apply(clean_venue)


print(match_result[['Venue', 'Is_Super_Over']].head())
# Out:
#                                                Venue Is_Super_Over
# 0                              Eden Gardens, Kolkata            No
# 1      Rajiv Gandhi International Stadium, Hyderabad            No
# 2                    MA Chidambaram Stadium, Chennai            No
# 3  Dr YS Rajasekhara Reddy ACA-VDCA Cricket Stadi...            No
# 4                   Narendra Modi Stadium, Ahmedabad            No

# %%
print(match_result.columns.tolist())
# Out:
# ['No', 'Match_No', 'Team1_Team2', 'Team1_Score', 'Team2_Score', 'Result', 'Date', 'Time', 'Venue', 'Is_Super_Over', 'Winner', 'Winning_Margin', 'Team1', 'Team2', 'Team1_Runs', 'Team1_Wickets', 'Team1_Overs', 'Team2_Runs', 'Team2_Wickets', 'Team2_Overs']

# %% [markdown]
# <span style="font-size: 20px; font-weight: bold;">1.8 - Restructure the DataFrame </span>

# %%
columns_to_drop = ['Team1_Team2', 'Team1_Score', 'Team2_Score', 'Result']
existing_columns_to_drop = [col for col in columns_to_drop if col in match_result.columns]

match_result = match_result.drop(columns=existing_columns_to_drop)

# Reorder columns for better readability (fixed the typo in column name)
column_order = ['Match_No', 'Date', 'Time', 'Team1', 'Team2', 'Team1_Runs', 'Team1_Wickets', 'Team1_Overs',
                'Team2_Runs', 'Team2_Wickets', 'Team2_Overs', 'Winner', 'Winning_Margin',
                'Venue', 'Is_Super_Over']
match_result = match_result[column_order]

# Check for missing values
print("\nMissing values in each column:")
print(match_result.isnull().sum())
# Out:
# Missing values in each column:
# Match_No          0
# Date              0
# Time              0
# Team1             0
# Team2             0
# Team1_Runs        0
# Team1_Wickets     0
# Team1_Overs       1
# Team2_Runs        2
# Team2_Wickets     2
# Team2_Overs       2
# Winner            4
# Winning_Margin    4
# Venue             0
# Is_Super_Over     0
# dtype: int64

# %% [markdown]
# <span style="font-size: 20px; font-weight: bold;">1.9 - Standardizing Team Names </span>

# %%
team_name_map = {
    'KKR': 'Kolkata Knight Riders',
    'RCB': 'Royal Challengers Bangalore',
    'GT': 'Gujarat Titans',
    'DC': 'Delhi Capitals',
    'MI': 'Mumbai Indians',
    'CSK': 'Chennai Super Kings',
    'PBKS': 'Punjab Kings',
    'LSG': 'Lucknow Super Giants',
    'SRH': 'Sunrisers Hyderabad'
}
# Replace short names with full names in Team1 and Team2
match_result['Team1'] = match_result['Team1'].replace(team_name_map)
match_result['Team2'] = match_result['Team2'].replace(team_name_map)

# %% [markdown]
# <span style="font-size: 20px; font-weight: bold;">2.0 - Save Data </span>

# %%
import os

Folder_name = 'Ipl Matches (2025)'
os.makedirs(Folder_name, exist_ok=True)  # Create folder if it doesn't exist

file_path = os.path.join(Folder_name, 'cleaned_match_results.csv')
match_result.to_csv(file_path, index=False)

print("\nCleaned data saved to:", file_path)
# Out:
# Cleaned data saved to: Ipl Matches (2025)\cleaned_match_results.csv

# %% [markdown]
# <span style="font-size: 25px; font-weight: bold;">Matches - Fixtures(2025)</span>

# %% [markdown]
# <span style="font-size: 20px; font-weight: bold;">2.1 Load the IPL matches fixture data</span>

# %%
try:
    match_fixtures = pd.read_csv("Ipl Matches (2025)/ipl_matches_Fixtures.csv")
    print("Successfully loaded ipl_matches_Fixtures.csv")
    print("Initial DataFrame shape:", match_fixtures.shape)
    print("\nFirst 5 rows:")
    print(match_fixtures.head())
except Exception as e:
    print(f"Error loading file: {e}")
# Out:
# Successfully loaded ipl_matches_Fixtures.csv
# Initial DataFrame shape: (16, 6)
#
# First 5 rows:
#    No  Match_No                              Team1_Team2         Date  \
# 0   1  Match 59              Lucknow Super Giants vs RCB   MAY, FRI 9
# 1   2  Match 60               Sunrisers Hyderabad vs KKR  MAY, SAT 10
# 2   3  Match 61           Punjab Kings vs Mumbai Indians  MAY, SUN 11
# 3   4  Match 62         Delhi Capitals vs Gujarat Titans  MAY, SUN 11
# 4   5  Match 63  Chennai Super Kings vs Rajasthan Royals  MAY, MON 12
#
#           Time                                              Venue
# 0  7:30 pm IST  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 1  7:30 pm IST      Rajiv Gandhi International Stadium, Hyderabad
# 2  3:30 pm IST                   Narendra Modi Stadium, Ahmedabad
# 3  7:30 pm IST                        Arun Jaitley Stadium, Delhi
# 4  7:30 pm IST                    MA Chidambaram Stadium, Chennai

# %% [markdown]
# <span style="font-size: 20px; font-weight: bold;">2.2 - Restructure the DataFrame </span>

# %%
# Clean column names
match_fixtures.columns = match_fixtures.columns.str.strip()
print("\nColumn names after cleaning:")
print(match_fixtures.columns.tolist())

# Check for missing values
print("\nMissing values in each column:")
print(match_fixtures.isnull().sum())

# Extract match number
match_fixtures['Match_Number'] = match_fixtures['Match_No'].str.extract(r'Match (\d+)').astype(int)
match_fixtures = match_fixtures.sort_values(by='Match_Number')
match_fixtures = match_fixtures.drop('Match_Number', axis=1).reset_index(drop=True)
# Out:
# Column names after cleaning:
# ['No', 'Match_No', 'Team1_Team2', 'Date', 'Time', 'Venue']
#
# Missing values in each column:
# No             0
# Match_No       0
# Team1_Team2    0
# Date           0
# Time           0
# Venue          0
# dtype: int64

# %% [markdown]
# <span style="font-size: 20px; font-weight: bold;">2.3 - Split Team1_Team2 into separate columns </span>

# %%
def extract_teams(team_str):
    if ' vs ' in team_str:
        teams = team_str.split(' vs ')
        return pd.Series(teams)
    return pd.Series([None, None])

match_fixtures[['Team1', 'Team2']] = match_fixtures['Team1_Team2'].apply(extract_teams)
match_fixtures
# Out:
#     No  Match_No                                  Team1_Team2         Date  \
# 0    1  Match 59                  Lucknow Super Giants vs RCB   MAY, FRI 9
# 1    2  Match 60                   Sunrisers Hyderabad vs KKR  MAY, SAT 10
# 2    3  Match 61               Punjab Kings vs Mumbai Indians  MAY, SUN 11
# 3    4  Match 62             Delhi Capitals vs Gujarat Titans  MAY, SUN 11
# 4    5  Match 63      Chennai Super Kings vs Rajasthan Royals  MAY, MON 12
# 5    6  Match 64                   RCB vs Sunrisers Hyderabad  MAY, TUE 13
# 6    7  Match 65       Gujarat Titans vs Lucknow Super Giants  MAY, WED 14
# 7    8  Match 66             Mumbai Indians vs Delhi Capitals  MAY, THU 15
# 8    9  Match 67             Rajasthan Royals vs Punjab Kings  MAY, FRI 16
# 9   10  Match 68                                   RCB vs KKR  MAY, SAT 17
# 10  11  Match 69        Gujarat Titans vs Chennai Super Kings  MAY, SUN 18
# 11  12  Match 70  Lucknow Super Giants vs Sunrisers Hyderabad  MAY, SUN 18
# 12  13  Match 71                                   TBD vs TBD  MAY, TUE 20
# 13  14  Match 72                                   TBD vs TBD  MAY, WED 21
# 14  15  Match 73                                   TBD vs TBD  MAY, FRI 23
# 15  16  Match 74                                   TBD vs TBD  MAY, SUN 25
#
#            Time                                              Venue  \
# 0   7:30 pm IST  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 1   7:30 pm IST      Rajiv Gandhi International Stadium, Hyderabad
# 2   3:30 pm IST                   Narendra Modi Stadium, Ahmedabad
# 3   7:30 pm IST                        Arun Jaitley Stadium, Delhi
# 4   7:30 pm IST                    MA Chidambaram Stadium, Chennai
# 5   7:30 pm IST                   M Chinnaswamy Stadium, Bengaluru
# 6   7:30 pm IST                   Narendra Modi Stadium, Ahmedabad
# 7   7:30 pm IST                           Wankhede Stadium, Mumbai
# 8   7:30 pm IST                     Sawai Mansingh Stadium, Jaipur
# 9   7:30 pm IST                   M Chinnaswamy Stadium, Bengaluru
# 10  3:30 pm IST                   Narendra Modi Stadium, Ahmedabad
# 11  7:30 pm IST  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 12  7:30 pm IST      Rajiv Gandhi International Stadium, Hyderabad
# 13  7:30 pm IST      Rajiv Gandhi International Stadium, Hyderabad
# 14  7:30 pm IST                              Eden Gardens, Kolkata
# 15  7:30 pm IST                              Eden Gardens, Kolkata
#
#                    Team1                 Team2
# 0   Lucknow Super Giants                   RCB
# 1    Sunrisers Hyderabad                   KKR
# 2           Punjab Kings        Mumbai Indians
# 3         Delhi Capitals        Gujarat Titans
# 4    Chennai Super Kings      Rajasthan Royals
# 5                    RCB   Sunrisers Hyderabad
# 6         Gujarat Titans  Lucknow Super Giants
# 7         Mumbai Indians        Delhi Capitals
# 8       Rajasthan Royals          Punjab Kings
# 9                    RCB                   KKR
# 10        Gujarat Titans   Chennai Super Kings
# 11  Lucknow Super Giants   Sunrisers Hyderabad
# 12                   TBD                   TBD
# 13                   TBD                   TBD
# 14                   TBD                   TBD
# 15                   TBD                   TBD

# %% [markdown]
# <span style="font-size: 20px; font-weight: bold;">2.4 - Clean Date Column </span>

# %%
import re
from datetime import datetime

def clean_date(date_str):
    date_fixtures = re.search(r'([A-Z]{3}, [A-Z]{3} \d{1,2})', date_str)
    if date_fixtures:
        date_part = date_fixtures.group(1)
        date_with_year = date_part + ', 2025'
        try:
            return datetime.strptime(date_with_year, '%b, %a %d, %Y')
        except ValueError:
            return None
    return None

match_fixtures['Date'] = match_fixtures['Date'].apply(clean_date)

print("\nCleaned date column:")
print(match_fixtures['Date'].head())
# Out:
# Cleaned date column:
# 0   2025-05-09
# 1   2025-05-10
# 2   2025-05-11
# 3   2025-05-11
# 4   2025-05-12
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# <span style="font-size: 20px; font-weight: bold;">2.5 - Clean time field </span>

# %%
def clean_time(time_str):
    if not isinstance(time_str, str):
        return None
    
    time_match = re.search(r'(\d{1,2}:\d{2})\s*([ap]m)', time_str.lower())
    if time_match:
        time_part = time_match.group(1)
        am_pm = time_match.group(2)
        
        hour, minute = map(int, time_part.split(':'))
        
        # Convert to 24-hour format
        if am_pm == 'pm' and hour < 12:
            hour += 12
        elif am_pm == 'am' and hour == 12:
            hour = 0
            
        return f"{hour:02d}:{minute:02d}"
    
    return None

match_fixtures['Time_Formatted'] = match_fixtures['Time'].apply(clean_time)

# %%
print(match_result.columns.tolist())
# Out:
# ['Match_No', 'Date', 'Time', 'Team1', 'Team2', 'Team1_Runs', 'Team1_Wickets', 'Team1_Overs', 'Team2_Runs', 'Team2_Wickets', 'Team2_Overs', 'Winner', 'Winning_Margin', 'Venue', 'Is_Super_Over']

# %% [markdown]
# <span style="font-size: 20px; font-weight: bold;">2.6 - cleaned DataFrame </span>

# %%
match_fixtures['Status'] = 'Scheduled'

match_fixtures[['Team1', 'Team2']] = match_fixtures['Team1_Team2'].str.split(' vs ', expand=True)

# Create the final cleaned DataFrame
cleaned_results = match_fixtures[[
    'No', 'Match_No', 'Team1', 'Team2',
     'Date', 'Time', 'Venue', 'Status'
]]

cleaned_results
# Out:
#     No  Match_No                 Team1                 Team2       Date  \
# 0    1  Match 59  Lucknow Super Giants                   RCB 2025-05-09
# 1    2  Match 60   Sunrisers Hyderabad                   KKR 2025-05-10
# 2    3  Match 61          Punjab Kings        Mumbai Indians 2025-05-11
# 3    4  Match 62        Delhi Capitals        Gujarat Titans 2025-05-11
# 4    5  Match 63   Chennai Super Kings      Rajasthan Royals 2025-05-12
# 5    6  Match 64                   RCB   Sunrisers Hyderabad 2025-05-13
# 6    7  Match 65        Gujarat Titans  Lucknow Super Giants 2025-05-14
# 7    8  Match 66        Mumbai Indians        Delhi Capitals 2025-05-15
# 8    9  Match 67      Rajasthan Royals          Punjab Kings 2025-05-16
# 9   10  Match 68                   RCB                   KKR 2025-05-17
# 10  11  Match 69        Gujarat Titans   Chennai Super Kings 2025-05-18
# 11  12  Match 70  Lucknow Super Giants   Sunrisers Hyderabad 2025-05-18
# 12  13  Match 71                   TBD                   TBD 2025-05-20
# 13  14  Match 72                   TBD                   TBD 2025-05-21
# 14  15  Match 73                   TBD                   TBD 2025-05-23
# 15  16  Match 74                   TBD                   TBD 2025-05-25
#
#            Time                                              Venue     Status
# 0   7:30 pm IST  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...  Scheduled
# 1   7:30 pm IST      Rajiv Gandhi International Stadium, Hyderabad  Scheduled
# 2   3:30 pm IST                   Narendra Modi Stadium, Ahmedabad  Scheduled
# 3   7:30 pm IST                        Arun Jaitley Stadium, Delhi  Scheduled
# 4   7:30 pm IST                    MA Chidambaram Stadium, Chennai  Scheduled
# 5   7:30 pm IST                   M Chinnaswamy Stadium, Bengaluru  Scheduled
# 6   7:30 pm IST                   Narendra Modi Stadium, Ahmedabad  Scheduled
# 7   7:30 pm IST                           Wankhede Stadium, Mumbai  Scheduled
# 8   7:30 pm IST                     Sawai Mansingh Stadium, Jaipur  Scheduled
# 9   7:30 pm IST                   M Chinnaswamy Stadium, Bengaluru  Scheduled
# 10  3:30 pm IST                   Narendra Modi Stadium, Ahmedabad  Scheduled
# 11  7:30 pm IST  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...  Scheduled
# 12  7:30 pm IST      Rajiv Gandhi International Stadium, Hyderabad  Scheduled
# 13  7:30 pm IST      Rajiv Gandhi International Stadium, Hyderabad  Scheduled
# 14  7:30 pm IST                              Eden Gardens, Kolkata  Scheduled
# 15  7:30 pm IST                              Eden Gardens, Kolkata  Scheduled

# %%
print(match_fixtures.columns)
# Out:
# Index(['No', 'Match_No', 'Team1_Team2', 'Date', 'Time', 'Venue', 'Team1',
#        'Team2', 'Time_Formatted', 'Status'],
#       dtype='object')

# %% [markdown]
# <span style="font-size: 20px; font-weight: bold;">2.7 - Standardizing IPL Fixture Data  </span>

# %%
cleaned_results['Team1'] = cleaned_results['Team1'].apply(lambda x: 'TBD' if x == 'TBD' else x)
cleaned_results['Team2'] = cleaned_results['Team2'].apply(lambda x: 'TBD' if x == 'TBD' else x)

team_name_map = {
    'KKR': 'Kolkata Knight Riders',
    'RCB': 'Royal Challengers Bangalore',
    'GT': 'Gujarat Titans',
    'DC': 'Delhi Capitals',
    'MI': 'Mumbai Indians',
    'CSK': 'Chennai Super Kings',
    'PBKS': 'Punjab Kings',
    'LSG': 'Lucknow Super Giants',
    'SRH': 'Sunrisers Hyderabad',
    'RR': 'Rajasthan Royals'
}

# Replace short names with full names
cleaned_results['Team1'] = cleaned_results['Team1'].replace(team_name_map)
cleaned_results['Team2'] = cleaned_results['Team2'].replace(team_name_map)

# Clean venue names
def clean_venue(venue_str):
    if isinstance(venue_str, str):
        return venue_str.strip()
    return None


cleaned_results
# Out:
# C:\Users\ajmal\AppData\Local\Temp\ipykernel_12076\1725719772.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_results['Team1'] = cleaned_results['Team1'].apply(lambda x: 'TBD' if x == 'TBD' else x)
# C:\Users\ajmal\AppData\Local\Temp\ipykernel_12076\1725719772.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_results['Team2'] = cleaned_results['Team2'].apply(lambda x: 'TBD' if x == 'TBD' else x)
# C:\Users\ajmal\AppData\Local\Temp\ipykernel_12076\1725719772.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_results['Team1'] = cleaned_results['Team1'].replace(team_name_map)
# C:\Users\ajmal\AppData\Local\Temp\ipykernel_12076\1725719772.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_results['Team2'] = cleaned_results['Team2'].replace(team_name_map)
#     No  Match_No                        Team1                        Team2  \
# 0    1  Match 59         Lucknow Super Giants  Royal Challengers Bangalore
# 1    2  Match 60          Sunrisers Hyderabad        Kolkata Knight Riders
# 2    3  Match 61                 Punjab Kings               Mumbai Indians
# 3    4  Match 62               Delhi Capitals               Gujarat Titans
# 4    5  Match 63          Chennai Super Kings             Rajasthan Royals
# 5    6  Match 64  Royal Challengers Bangalore          Sunrisers Hyderabad
# 6    7  Match 65               Gujarat Titans         Lucknow Super Giants
# 7    8  Match 66               Mumbai Indians               Delhi Capitals
# 8    9  Match 67             Rajasthan Royals                 Punjab Kings
# 9   10  Match 68  Royal Challengers Bangalore        Kolkata Knight Riders
# 10  11  Match 69               Gujarat Titans          Chennai Super Kings
# 11  12  Match 70         Lucknow Super Giants          Sunrisers Hyderabad
# 12  13  Match 71                          TBD                          TBD
# 13  14  Match 72                          TBD                          TBD
# 14  15  Match 73                          TBD                          TBD
# 15  16  Match 74                          TBD                          TBD
#
#          Date         Time                                              Venue  \
# 0  2025-05-09  7:30 pm IST  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 1  2025-05-10  7:30 pm IST      Rajiv Gandhi International Stadium, Hyderabad
# 2  2025-05-11  3:30 pm IST                   Narendra Modi Stadium, Ahmedabad
# 3  2025-05-11  7:30 pm IST                        Arun Jaitley Stadium, Delhi
# 4  2025-05-12  7:30 pm IST                    MA Chidambaram Stadium, Chennai
# 5  2025-05-13  7:30 pm IST                   M Chinnaswamy Stadium, Bengaluru
# 6  2025-05-14  7:30 pm IST                   Narendra Modi Stadium, Ahmedabad
# 7  2025-05-15  7:30 pm IST                           Wankhede Stadium, Mumbai
# 8  2025-05-16  7:30 pm IST                     Sawai Mansingh Stadium, Jaipur
# 9  2025-05-17  7:30 pm IST                   M Chinnaswamy Stadium, Bengaluru
# 10 2025-05-18  3:30 pm IST                   Narendra Modi Stadium, Ahmedabad
# 11 2025-05-18  7:30 pm IST  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 12 2025-05-20  7:30 pm IST      Rajiv Gandhi International Stadium, Hyderabad
# 13 2025-05-21  7:30 pm IST      Rajiv Gandhi International Stadium, Hyderabad
# 14 2025-05-23  7:30 pm IST                              Eden Gardens, Kolkata
# 15 2025-05-25  7:30 pm IST                              Eden Gardens, Kolkata
#
#        Status
# 0   Scheduled
# 1   Scheduled
# 2   Scheduled
# 3   Scheduled
# 4   Scheduled
# 5   Scheduled
# 6   Scheduled
# 7   Scheduled
# 8   Scheduled
# 9   Scheduled
# 10  Scheduled
# 11  Scheduled
# 12  Scheduled
# 13  Scheduled
# 14  Scheduled
# 15  Scheduled

# %%
print(match_fixtures.columns.tolist())
# Out:
# ['No', 'Match_No', 'Team1_Team2', 'Date', 'Time', 'Venue', 'Team1', 'Team2', 'Time_Formatted', 'Status']

# %% [markdown]
# <span style="font-size: 20px; font-weight: bold;">2.8 - cleaned DataFrame </span>

# %%
# Check for missing values
print("\nMissing values in each column:")
print(cleaned_results.isnull().sum())
# Out:
# Missing values in each column:
# No          0
# Match_No    0
# Team1       0
# Team2       0
# Date        0
# Time        0
# Venue       0
# Status      0
# dtype: int64

# %% [markdown]
# <span style="font-size: 20px; font-weight: bold;">2.9 - Save Data </span>

# %%
# Display final cleaned DataFrame
print("\nFinal cleaned DataFrame:")
print(cleaned_results.head())
print("\nDataFrame shape:", cleaned_results.shape)

# Save the cleaned data
folder_name = 'Ipl Matches (2025)'
os.makedirs(folder_name, exist_ok=True)

file_path = os.path.join(folder_name, 'cleaned_ipl_fixtures.csv')
cleaned_results.to_csv(file_path, index=False)

print(f"\nCleaned fixture data saved to: {file_path}")
# Out:
# Final cleaned DataFrame:
#    No  Match_No                 Team1                        Team2       Date  \
# 0   1  Match 59  Lucknow Super Giants  Royal Challengers Bangalore 2025-05-09
# 1   2  Match 60   Sunrisers Hyderabad        Kolkata Knight Riders 2025-05-10
# 2   3  Match 61          Punjab Kings               Mumbai Indians 2025-05-11
# 3   4  Match 62        Delhi Capitals               Gujarat Titans 2025-05-11
# 4   5  Match 63   Chennai Super Kings             Rajasthan Royals 2025-05-12
#
#           Time                                              Venue     Status
# 0  7:30 pm IST  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...  Scheduled
# 1  7:30 pm IST      Rajiv Gandhi International Stadium, Hyderabad  Scheduled
# 2  3:30 pm IST                   Narendra Modi Stadium, Ahmedabad  Scheduled
# 3  7:30 pm IST                        Arun Jaitley Stadium, Delhi  Scheduled
# 4  7:30 pm IST                    MA Chidambaram Stadium, Chennai  Scheduled
#
# DataFrame shape: (16, 8)
#
# Cleaned fixture data saved to: Ipl Matches (2025)\cleaned_ipl_fixtures.csv

# %% [markdown]
# <span style="font-size: 25px; font-weight: bold;">Combined Ipl_fixtures & Match_results</span>

# %%
import pandas as pd
import os

# Define file paths
fixtures_path = "Ipl Matches (2025)/cleaned_ipl_fixtures.csv"
results_path = "Ipl Matches (2025)/cleaned_match_results.csv"
output_path = "Ipl Matches (2025)/combined_ipl_data_2025.csv"

def combine_ipl_data():
    # Read the CSV files
    try:
        fixtures_df = pd.read_csv(fixtures_path)
        results_df = pd.read_csv(results_path)
        
        print(f"Fixtures data shape: {fixtures_df.shape}")
        print(f"Results data shape: {results_df.shape}")
        
        # Display sample data
        print("\nFixtures sample:")
        print(fixtures_df.head(2))
        print("\nResults sample:")
        print(results_df.head(2))
        
        # Create a common key for merging based on teams and date/time
        fixtures_df['merge_key'] = fixtures_df['Date'] + "_" + fixtures_df['Time'] + "_" + fixtures_df['Team1'] + "_" + fixtures_df['Team2']
        results_df['merge_key'] = results_df['Date'] + "_" + results_df['Time'] + "_" + results_df['Team1'] + "_" + results_df['Team2']
        
        # Perform an outer merge to keep all matches (both with and without results)
        combined_df = pd.merge(fixtures_df, results_df, on='merge_key', how='outer', suffixes=('_fixture', '_result'))
        
        # Clean up the merged dataframe
        # For columns present in both dataframes, keep one version and handle conflicts
        combined_df['Date'] = combined_df['Date_fixture'].fillna(combined_df['Date_result'])
        combined_df['Time'] = combined_df['Time_fixture'].fillna(combined_df['Time_result'])
        combined_df['Team1'] = combined_df['Team1_fixture'].fillna(combined_df['Team1_result'])
        combined_df['Team2'] = combined_df['Team2_fixture'].fillna(combined_df['Team2_result'])
        combined_df['Venue'] = combined_df['Venue_fixture'].fillna(combined_df['Venue_result'])
        
        # Handle Match_No - create sequential match numbers (Match 1, Match 2, etc.)
        combined_df['Match_No'] = ["Match " + str(i+1) for i in range(len(combined_df))]
        
        # Update Status to "Completed" for matches that have results
        combined_df['Status'] = combined_df['Status']
        has_result = combined_df['Winner'].notna()
        combined_df.loc[has_result, 'Status'] = "Completed"
        
        # Fill empty numeric fields with 0
        numeric_columns = ['Team1_Runs', 'Team1_Wickets', 'Team2_Runs', 'Team2_Wickets']
        for column in numeric_columns:
            if column in combined_df.columns:
                combined_df[column] = combined_df[column].fillna(0).astype(int)
        
        # Fill empty over columns with "0.0"
        over_columns = ['Team1_Overs', 'Team2_Overs']
        for column in over_columns:
            if column in combined_df.columns:
                combined_df[column] = combined_df[column].fillna("0.0")
        
        # Fill empty text fields with appropriate placeholders
        combined_df['Winner'] = combined_df['Winner'].fillna("")
        combined_df['Winning_Margin'] = combined_df['Winning_Margin'].fillna("")
        
        # Fill Is_Super_Over with False (or 0) for matches without results
        if 'Is_Super_Over' in combined_df.columns:
            combined_df['Is_Super_Over'] = combined_df['Is_Super_Over'].fillna(False)
        
        # Drop redundant columns
        columns_to_drop = ['Date_fixture', 'Date_result', 'Time_fixture', 'Time_result', 
                           'Team1_fixture', 'Team1_result', 'Team2_fixture', 'Team2_result', 
                           'Venue_fixture', 'Venue_result', 'merge_key']
        
        # Also drop original Match_No columns if they exist with suffixes
        if 'Match_No_fixture' in combined_df.columns:
            columns_to_drop.append('Match_No_fixture')
        if 'Match_No_result' in combined_df.columns:
            columns_to_drop.append('Match_No_result')
            
        combined_df = combined_df.drop(columns=[col for col in columns_to_drop if col in combined_df.columns])
        
        # Reorder columns for better readability
        column_order = ['Match_No', 'Date', 'Time', 'Team1', 'Team2', 'Venue', 'Status',
                        'Team1_Runs', 'Team1_Wickets', 'Team1_Overs', 
                        'Team2_Runs', 'Team2_Wickets', 'Team2_Overs',
                        'Winner', 'Winning_Margin', 'Is_Super_Over']
        
        # Filter to only include columns that exist in the dataframe
        existing_columns = [col for col in column_order if col in combined_df.columns]
        combined_df = combined_df[existing_columns]
        
        # Save the combined data
        combined_df.to_csv(output_path, index=False)
        print(f"\nSuccessfully combined data and saved to {output_path}")
        print(f"Combined data shape: {combined_df.shape}")
        
        # Display sample of Match_No column to verify format
        print("\nMatch_No column sample:")
        print(combined_df['Match_No'].head(5).tolist())
        
        return combined_df
        
    except Exception as e:
        print(f"Error processing files: {e}")
        return None

if __name__ == "__main__":
    # Check if files exist
    if not os.path.exists(fixtures_path):
        print(f"Error: Fixtures file not found at {fixtures_path}")
    elif not os.path.exists(results_path):
        print(f"Error: Results file not found at {results_path}")
    else:
        combined_data = combine_ipl_data()
        
        if combined_data is not None:
            # Display sample of the combined data
            print("\nCombined data sample:")
            print(combined_data.head())
            
            # Count matches by status
            status_counts = combined_data['Status'].value_counts()
            print("\nMatch status summary:")
            print(status_counts)
# Out:
# Fixtures data shape: (16, 8)
# Results data shape: (58, 15)
#
# Fixtures sample:
#    No  Match_No                 Team1                        Team2  \
# 0   1  Match 59  Lucknow Super Giants  Royal Challengers Bangalore
# 1   2  Match 60   Sunrisers Hyderabad        Kolkata Knight Riders
#
#          Date         Time                                              Venue  \
# 0  2025-05-09  7:30 pm IST  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 1  2025-05-10  7:30 pm IST      Rajiv Gandhi International Stadium, Hyderabad
#
#       Status
# 0  Scheduled
# 1  Scheduled
#
# Results sample:
#   Match_No        Date      Time                  Team1  \
# 0  Match 1  2025-03-22  19:30:00  Kolkata Knight Riders
# 1  Match 2  2025-03-23  15:30:00    Sunrisers Hyderabad
#
#                          Team2  Team1_Runs  Team1_Wickets  Team1_Overs  \
# 0  Royal Challengers Bangalore         174              8         20.0
# 1             Rajasthan Royals         286              6         20.0
#
#    Team2_Runs  Team2_Wickets  Team2_Overs                       Winner  \
# 0       177.0            3.0         16.2  Royal Challengers Bengaluru
# 1       242.0            6.0         20.0          Sunrisers Hyderabad
#
#   Winning_Margin                                          Venue Is_Super_Over
# 0      7 Wickets                          Eden Gardens, Kolkata            No
# 1        44 Runs  Rajiv Gandhi International Stadium, Hyderabad            No
#
# Successfully combined data and saved to Ipl Matches (2025)/combined_ipl_data_2025.csv
# Combined data shape: (74, 16)
#
# Match_No column sample:
# ['Match 1', 'Match 2', 'Match 3', 'Match 4', 'Match 5']
#
# Combined data sample:
#   Match_No        Date      Time                  Team1  \
# 0  Match 1  2025-03-22  19:30:00  Kolkata Knight Riders
# 1  Match 2  2025-03-23  15:30:00    Sunrisers Hyderabad
# 2  Match 3  2025-03-23  19:30:00    Chennai Super Kings
# 3  Match 4  2025-03-24  19:30:00         Delhi Capitals
# 4  Match 5  2025-03-25  19:30:00         Gujarat Titans
#
#                          Team2  \
# 0  Royal Challengers Bangalore
# 1             Rajasthan Royals
# 2               Mumbai Indians
# 3         Lucknow Super Giants
# 4                 Punjab Kings
#
#                                                Venue     Status  Team1_Runs  \
# 0                              Eden Gardens, Kolkata  Completed         174
# 1      Rajiv Gandhi International Stadium, Hyderabad  Completed         286
# 2                    MA Chidambaram Stadium, Chennai  Completed         158
# 3  Dr YS Rajasekhara Reddy ACA-VDCA Cricket Stadi...  Completed         211
# 4                   Narendra Modi Stadium, Ahmedabad  Completed         232
#
#    Team1_Wickets Team1_Overs  Team2_Runs  Team2_Wickets Team2_Overs  \
# 0              8        20.0         177              3        16.2
# 1              6        20.0         242              6        20.0
# 2              6        19.1         155              9        20.0
# 3              9        19.3         209              8        20.0
# 4              5        20.0         243              5        20.0
#
#                         Winner Winning_Margin Is_Super_Over
# 0  Royal Challengers Bengaluru      7 Wickets            No
# 1          Sunrisers Hyderabad        44 Runs            No
# 2          Chennai Super Kings      4 Wickets            No
# 3               Delhi Capitals       1 Wicket            No
# 4                 Punjab Kings        11 Runs            No
#
# Match status summary:
# Status
# Completed    54
# Scheduled    16
# Name: count, dtype: int64

# %% [markdown]
# <span style="font-size: 25px; font-weight: bold;">IPL Points Tables - (2008 - 2025)</span>

# %%
import pandas as pd
import os
import glob
import re

# Define the directory containing the CSV files
data_dir = "IPL Points Tables/Tables"

# Check if directory exists
if not os.path.exists(data_dir):
    print(f"Directory '{data_dir}' does not exist. Creating it...")
    os.makedirs(data_dir)
    print("Please place your IPL points table CSV files in this directory.")
    exit()

# Get all CSV files in the directory
csv_files = glob.glob(os.path.join(data_dir, "IPL_Points_Table_*.csv"))

if len(csv_files) == 0:
    print(f"No CSV files found in '{data_dir}'. Please add your IPL points table CSV files.")
    exit()

# Function to extract year from filename
def extract_year(filename):
    match = re.search(r'(\d{4})', filename)
    if match:
        return int(match.group(1))
    return None

# List to store individual dataframes
all_dfs = []

# Read each CSV file and add a year column
for file in sorted(csv_files, key=extract_year):
    year = extract_year(file)
    if year:
        try:
            df = pd.read_csv(file)
            
            # Add year column
            df['Season'] = year
            
            # Standardize column names (if they vary between files)
            if 'TEAM' in df.columns:
                df.rename(columns={'TEAM': 'Team'}, inplace=True)
            if 'P' in df.columns:
                df.rename(columns={'P': 'Matches'}, inplace=True)
            if 'W' in df.columns:
                df.rename(columns={'W': 'Wins'}, inplace=True)
            if 'L' in df.columns:
                df.rename(columns={'L': 'Losses'}, inplace=True)
            if 'NR' in df.columns:
                df.rename(columns={'NR': 'No_Result'}, inplace=True)
            if 'NRR' in df.columns:
                df.rename(columns={'NRR': 'Net_Run_Rate'}, inplace=True)
            if 'PTS' in df.columns:
                df.rename(columns={'PTS': 'Points'}, inplace=True)
                
            # Clean team names (if needed)
            if 'Team' in df.columns:
                # Remove any special characters or trailing spaces
                df['Team'] = df['Team'].str.strip()
            
            # Append to list
            all_dfs.append(df)
            print(f"Processed {file} - Year: {year}")
        except Exception as e:
            print(f"Error processing {file}: {e}")
    else:
        print(f"Could not extract year from {file}. Skipping...")

# Check if we have data to combine
if len(all_dfs) == 0:
    print("No data was successfully loaded. Please check your CSV files.")
    exit()

# Combine all dataframes
combined_df = pd.concat(all_dfs, ignore_index=True)

# Sort by year and then by position
combined_df = combined_df.sort_values(by=['Season'])

# Additional cleaning
# Convert numeric columns to appropriate types
numeric_cols = ['Matches', 'Wins', 'Losses', 'No_Result', 'Net_Run_Rate', 'Points']
for col in numeric_cols:
    if col in combined_df.columns:
        try:
            if col == 'Net_Run_Rate':
                combined_df[col] = pd.to_numeric(combined_df[col], errors='coerce')
            else:
                combined_df[col] = pd.to_numeric(combined_df[col], errors='coerce').fillna(0).astype(int)
        except Exception as e:
            print(f"Error converting {col} to numeric: {e}")

# Standardize team names (mapping variations of the same team)
team_mapping = {
    'DD': 'Delhi Daredevils',
    'DC': 'Delhi Capitals',  # Renamed from Delhi Daredevils
    'PBKS': 'Punjab Kings',  # Renamed from Kings XI Punjab
    'KXIP': 'Punjab Kings',
    'CSK': 'Chennai Super Kings',
    'MI': 'Mumbai Indians',
    'KKR': 'Kolkata Knight Riders',
    'RCB': 'Royal Challengers Bangalore',
    'RR': 'Rajasthan Royals',
    'SRH': 'Sunrisers Hyderabad',
    'DEC': 'Deccan Chargers',
    'GL': 'Gujarat Lions',
    'RPS': 'Rising Pune Supergiant',
    'PWI': 'Pune Warriors India',
    'KTK': 'Kochi Tuskers Kerala',
    'GT': 'Gujarat Titans',
    'LSG': 'Lucknow Super Giants'
}

# Apply team name standardization if Team column exists
if 'Team' in combined_df.columns:
    combined_df['Team'] = combined_df['Team'].map(lambda x: team_mapping.get(x, x))

# Save the combined dataset
output_dir = 'Tables'
os.makedirs(output_dir, exist_ok=True)

output_path = os.path.join(output_dir, "IPL - Points Table - 2008 to 2025.csv")
combined_df.to_csv(output_path, index=False)

print(f"Fixtures data saved to: {output_path}")

# Print stats about the combined dataset
print("\nDataset Statistics:")
print(f"Total records: {len(combined_df)}")
print(f"Years covered: {combined_df['Season'].min()} to {combined_df['Season'].max()}")
print(f"Teams included: {combined_df['Team'].nunique()}")

# Basic analysis
if 'Team' in combined_df.columns and 'Wins' in combined_df.columns:
    team_wins = combined_df.groupby('Team')['Wins'].sum().sort_values(ascending=False)
    print("\nTotal Wins by Team:")
    print(team_wins)

if 'Team' in combined_df.columns and 'Points' in combined_df.columns:
    team_points = combined_df.groupby('Team')['Points'].sum().sort_values(ascending=False)
    print("\nTotal Points by Team:")
    print(team_points)
# Out:
# Processed IPL Points Tables/Tables\IPL_Points_Table_2008.csv - Year: 2008
# Processed IPL Points Tables/Tables\IPL_Points_Table_2009.csv - Year: 2009
# Processed IPL Points Tables/Tables\IPL_Points_Table_2010.csv - Year: 2010
# Processed IPL Points Tables/Tables\IPL_Points_Table_2011.csv - Year: 2011
# Processed IPL Points Tables/Tables\IPL_Points_Table_2012.csv - Year: 2012
# Processed IPL Points Tables/Tables\IPL_Points_Table_2013.csv - Year: 2013
# Processed IPL Points Tables/Tables\IPL_Points_Table_2014.csv - Year: 2014
# Processed IPL Points Tables/Tables\IPL_Points_Table_2015.csv - Year: 2015
# Processed IPL Points Tables/Tables\IPL_Points_Table_2016.csv - Year: 2016
# Processed IPL Points Tables/Tables\IPL_Points_Table_2017.csv - Year: 2017
# Processed IPL Points Tables/Tables\IPL_Points_Table_2018.csv - Year: 2018
# Processed IPL Points Tables/Tables\IPL_Points_Table_2019.csv - Year: 2019
# Processed IPL Points Tables/Tables\IPL_Points_Table_2020.csv - Year: 2020
# Processed IPL Points Tables/Tables\IPL_Points_Table_2021.csv - Year: 2021
# Processed IPL Points Tables/Tables\IPL_Points_Table_2022.csv - Year: 2022
# Processed IPL Points Tables/Tables\IPL_Points_Table_2023.csv - Year: 2023
# Processed IPL Points Tables/Tables\IPL_Points_Table_2024.csv - Year: 2024
# Processed IPL Points Tables/Tables\IPL_Points_Table_2025.csv - Year: 2025
# Fixtures data saved to: Tables\IPL - Points Table - 2008 to 2025.csv
#
# Dataset Statistics:
# Total records: 156
# Years covered: 2008 to 2025
# Teams included: 16
#
# Total Points by Team:
# Team
# Mumbai Indians                 277
# Kolkata Knight Riders          259
# Royal Challengers Bangalore    256
# Chennai Super Kings            249
# Punjab Kings                   237
# Rajasthan Royals               226
# Sunrisers Hyderabad            173
# Delhi Daredevils               137
# Delhi Capitals                 105
# Gujarat Titans                  66
# Lucknow Super Giants            59
# Deccan Chargers                 55
# Rising Pune Supergiant          28
# Gujarat Lions                   26
# Pune Warriors India             25
# Kochi Tuskers Kerala            12
# Name: Points, dtype: int64

# %% [markdown]
# <span style="font-size: 25px; font-weight: bold;"> Data Cleaning For The ipl_match_data_matches</span>

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("Ipl Matches (2025)/ipl_match_data_matches.csv")

# Rename column
df.rename(columns={'MOM': 'Player_of_Match'}, inplace=True)

# Split umpires into two columns
df[['Umpire1', 'Umpire2']] = df['On_Field_Umpire'].str.split(',', expand=True)
df['Umpire1'] = df['Umpire1'].str.strip()
df['Umpire2'] = df['Umpire2'].str.strip()

# Replace 'On_Field_Umpire' with 'Umpire1' and 'Umpire2' in the same position
umpire_index = df.columns.get_loc('On_Field_Umpire')
df.drop(columns=['On_Field_Umpire'], inplace=True)
df.insert(umpire_index, 'Umpire2', df.pop('Umpire2'))
df.insert(umpire_index, 'Umpire1', df.pop('Umpire1'))

# Add 'Match ' prefix to Match_No, ensuring it's numeric first
df['Match_No'] = 'Match ' + df['Match_No'].astype(str).str.extract(r'(\d+)', expand=False)

# Save cleaned file
df.to_csv("Ipl Matches (2025)/ipl_match_data_cleaned.csv", index=False)

print("Transformation complete. File saved as 'ipl_match_data_cleaned.csv'")
# Out:
# Transformation complete. File saved as 'ipl_match_data_cleaned.csv'

# %% [markdown]
# <span style="font-size: 25px; font-weight: bold;">Preprocessing Combined_ipl_data_2025</span>

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv("Ipl Matches (2025)/combined_ipl_data_2025.csv") 

# Step 1: Replace FALSE with 'No'
df.replace("FALSE", "No", inplace=True)

# Step 2: Split Winning_Margin into WonBy and Margin
df[['Margin', 'WonBy']] = df['Winning_Margin'].str.extract(r'(\d+\.?\d*)\s*(\w+)')
df['Margin'] = df['Margin'].astype(float)  # convert margin to float

# Step 3: Drop original Winning_Margin column
df.drop(columns=['Winning_Margin'], inplace=True)

# Save the cleaned DataFrame to a new CSV file
df.to_csv("Ipl Matches (2025)/cleaned_ipl_data_2025.csv", index=False)

# Display the cleaned DataFrame
print(df.head())
# Out:
#   Match_No        Date      Time                  Team1  \
# 0  Match 1  2025-03-22  19:30:00  Kolkata Knight Riders
# 1  Match 2  2025-03-23  15:30:00    Sunrisers Hyderabad
# 2  Match 3  2025-03-23  19:30:00    Chennai Super Kings
# 3  Match 4  2025-03-24  19:30:00         Delhi Capitals
# 4  Match 5  2025-03-25  19:30:00         Gujarat Titans
#
#                          Team2  \
# 0  Royal Challengers Bangalore
# 1             Rajasthan Royals
# 2               Mumbai Indians
# 3         Lucknow Super Giants
# 4                 Punjab Kings
#
#                                                Venue     Status  Team1_Runs  \
# 0                              Eden Gardens, Kolkata  Completed         174
# 1      Rajiv Gandhi International Stadium, Hyderabad  Completed         286
# 2                    MA Chidambaram Stadium, Chennai  Completed         158
# 3  Dr YS Rajasekhara Reddy ACA-VDCA Cricket Stadi...  Completed         211
# 4                   Narendra Modi Stadium, Ahmedabad  Completed         232
#
#    Team1_Wickets  Team1_Overs  Team2_Runs  Team2_Wickets  Team2_Overs  \
# 0              8         20.0         177              3         16.2
# 1              6         20.0         242              6         20.0
# 2              6         19.1         155              9         20.0
# 3              9         19.3         209              8         20.0
# 4              5         20.0         243              5         20.0
#
#                         Winner Is_Super_Over  Margin    WonBy
# 0  Royal Challengers Bengaluru            No     7.0  Wickets
# 1          Sunrisers Hyderabad            No    44.0     Runs
# 2          Chennai Super Kings            No     4.0  Wickets
# 3               Delhi Capitals            No     1.0   Wicket
# 4                 Punjab Kings            No    11.0     Runs

# %% [markdown]
# <span style="font-size: 25px; font-weight: bold;">Combining</span>

# %%
import pandas as pd

df1 = pd.read_csv("Ipl Matches (2025)/ipl_match_data_cleaned.csv")  # Replace with correct path
df2 = pd.read_csv("Ipl Matches (2025)/cleaned_ipl_data_2025.csv")  # Replace with correct path

df1['Match_No'] = df1['Match_No'].astype(str)
df2['Match_No'] = df2['Match_No'].astype(str)

df_combined = pd.merge(df1, df2, on="Match_No", how="outer")

df_combined.fillna("N/A", inplace=True)

# Ensure the 'Match_No' column is sorted in ascending order
df_combined['Match_No'] = pd.to_numeric(df_combined['Match_No'].str.extract('(\d+)')[0])
df_combined = df_combined.sort_values(by='Match_No').reset_index(drop=True)

# Convert 'Match_No' back to 'Match X' format
df_combined['Match_No'] = 'Match ' + df_combined['Match_No'].astype(str)

df_combined.to_csv("Ipl Matches (2025)/combined_ipl_data_2025.csv", index=False)

print(df_combined.head())
# Out:
#   Match_No                Umpire1                Umpire2  \
# 0  Match 1           Vinod Seshan           Vinod Seshan
# 1  Match 2       Adrian Holdstock       Adrian Holdstock
# 2  Match 3  Kn Ananthapadmanabhan  Kn Ananthapadmanabhan
# 3  Match 4           Ulhas Gandhe           Ulhas Gandhe
# 4  Match 5           Vinod Seshan           Vinod Seshan
#
#             Third_Umpire           Referee  Player_of_Match  \
# 0           Vinod Seshan     Prakash Bhatt    Krunal Pandya
# 1       Adrian Holdstock      Shakti Singh     Ishan Kishan
# 2  Kn Ananthapadmanabhan   Javagal Srinath       Noor Ahmad
# 3           Ulhas Gandhe  Narayanankutty V  Ashutosh Sharma
# 4           Vinod Seshan     Prakash Bhatt     Shreyas Iyer
#
#                    Toss_Winner Toss_Decision                 Match_Winner  \
# 0  Royal Challengers Bengaluru         Field  Royal Challengers Bengaluru
# 1             Rajasthan Royals         Field          Sunrisers Hyderabad
# 2          Chennai Super Kings         Field          Chennai Super Kings
# 3               Delhi Capitals         Field               Delhi Capitals
# 4               Gujarat Titans         Field                 Punjab Kings
#
#   Result_Margin  ... Team1_Runs Team1_Wickets Team1_Overs Team2_Runs  \
# 0    7  Wickets  ...        174             8        20.0        177
# 1      44  Runs  ...        286             6        20.0        242
# 2    4  Wickets  ...        158             6        19.1        155
# 3           N/A  ...        211             9        19.3        209
# 4      11  Runs  ...        232             5        20.0        243
#
#   Team2_Wickets Team2_Overs                       Winner  Is_Super_Over  \
# 0             3        16.2  Royal Challengers Bengaluru             No
# 1             6        20.0          Sunrisers Hyderabad             No
# 2             9        20.0          Chennai Super Kings             No
# 3             8        20.0               Delhi Capitals             No
# 4             5        20.0                 Punjab Kings             No
#
#    Margin    WonBy
# 0     7.0  Wickets
# 1    44.0     Runs
# 2     4.0  Wickets
# 3     1.0   Wicket
# 4    11.0     Runs
#
# [5 rows x 26 columns]
# C:\Users\ajmal\AppData\Local\Temp\ipykernel_12076\3136543637.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'N/A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_combined.fillna("N/A", inplace=True)

# %% [markdown]
# <span style="font-size: 25px; font-weight: bold;">Combined_ipl_data_2025 & team_details</span>

# %%
import pandas as pd

matches_df = pd.read_csv('Ipl Matches (2025)/combined_ipl_data_2025.csv')
teams_df = pd.read_csv('Ipl Matches (2025)/team_details.csv')

team_name_standardization = {
    'Royal Challengers Bangalore': 'Royal Challengers Bengaluru'
}

matches_df['Team1'] = matches_df['Team1'].replace(team_name_standardization)
matches_df['Team2'] = matches_df['Team2'].replace(team_name_standardization)
matches_df['Winner'] = matches_df['Winner'].replace(team_name_standardization)

combined_df = pd.merge(matches_df, teams_df, how='left', left_on='Team1', right_on='Team')
combined_df = pd.merge(combined_df, teams_df, how='left', left_on='Team2', right_on='Team', suffixes=('_Team1', '_Team2'))
combined_df.drop(columns=['Team_Team1', 'Team_Team2'], inplace=True)
combined_df.to_csv('Ipl Matches (2025)/combined_ipl_data_with_teams.csv', index=False)
print(combined_df.head())
# Out:
#   Match_No                Umpire1                Umpire2  \
# 0  Match 1           Vinod Seshan           Vinod Seshan
# 1  Match 2       Adrian Holdstock       Adrian Holdstock
# 2  Match 3  Kn Ananthapadmanabhan  Kn Ananthapadmanabhan
# 3  Match 4           Ulhas Gandhe           Ulhas Gandhe
# 4  Match 5           Vinod Seshan           Vinod Seshan
#
#             Third_Umpire           Referee  Player_of_Match  \
# 0           Vinod Seshan     Prakash Bhatt    Krunal Pandya
# 1       Adrian Holdstock      Shakti Singh     Ishan Kishan
# 2  Kn Ananthapadmanabhan   Javagal Srinath       Noor Ahmad
# 3           Ulhas Gandhe  Narayanankutty V  Ashutosh Sharma
# 4           Vinod Seshan     Prakash Bhatt     Shreyas Iyer
#
#                    Toss_Winner Toss_Decision                 Match_Winner  \
# 0  Royal Challengers Bengaluru         Field  Royal Challengers Bengaluru
# 1             Rajasthan Royals         Field          Sunrisers Hyderabad
# 2          Chennai Super Kings         Field          Chennai Super Kings
# 3               Delhi Capitals         Field               Delhi Capitals
# 4               Gujarat Titans         Field                 Punjab Kings
#
#   Result_Margin  ... Margin    WonBy   Captain_Team1         Coach_Team1  \
# 0    7  Wickets  ...    7.0  Wickets  Ajinkya Rahane  Chandrakant Pandit
# 1      44  Runs  ...   44.0     Runs     Pat Cummins      Daniel Vettori
# 2    4  Wickets  ...    4.0  Wickets        MS Dhoni     Stephen Fleming
# 3           NaN  ...    1.0   Wicket      Axar Patel       Hemang Badani
# 4      11  Runs  ...   11.0     Runs    Shubman Gill        Ashish Nehra
#
#                             Owner_Team1                             Venue_y  \
# 0  Knight Riders Sports Private Limited                        Eden Gardens
# 1                Sun TV Network Limited  Rajiv Gandhi Intl. Cricket Stadium
# 2   Chennai Super Kings Cricket Limited           M. A. Chidambaram Stadium
# 3               JSW GMR Cricket Pvt Ltd                Arun Jaitley Stadium
# 4   Irelia Sports India Private Limited               Narendra Modi Stadium
#
#    Captain_Team2         Coach_Team2                           Owner_Team2  \
# 0  Rajat Patidar         Andy Flower  Royal Challengers Sports Private Ltd
# 1   Sanju Samson        Rahul Dravid      Royal Multisport Private Limited
# 2  Hardik Pandya  Mahela Jayawardene              Indiawin Sports Pvt. Ltd
# 3   Rishabh Pant       Justin Langer           RPSG Sports Private Limited
# 4   Shreyas Iyer       Ricky Ponting  K.P.H. Dream Cricket Private Limited
#
#                           Venue
# 0        M. Chinnaswamy Stadium
# 1        Sawai Mansingh Stadium
# 2              Wankhede Stadium
# 3  BRSABV Ekana Cricket Stadium
# 4    PCA New Stadium, Mullanpur
#
# [5 rows x 34 columns]

# %%
print(df.columns)
# Out:
# Index(['Match_No', 'Umpire1', 'Umpire2', 'Third_Umpire', 'Referee',
#        'Player_of_Match', 'Toss_Winner', 'Toss_Decision', 'Match_Winner',
#        'Result_Margin', 'Date', 'Time', 'Team1', 'Team2', 'Venue_x', 'Status',
#        'Team1_Runs', 'Team1_Wickets', 'Team1_Overs', 'Team2_Runs',
#        'Team2_Wickets', 'Team2_Overs', 'Winner', 'Is_Super_Over', 'Margin',
#        'WonBy', 'Captain_Team1', 'Coach_Team1', 'Owner_Team1', 'Venue_y',
#        'Captain_Team2', 'Coach_Team2', 'Owner_Team2', 'Venue'],
#       dtype='object')

# %%
import pandas as pd
import os

# Define the path
file_path = "Ipl Matches (2025)/combined_ipl_data_with_teams.csv"
output_path = "Ipl Matches (2025)/Final2025IPL.csv"

# Ensure directory exists
os.makedirs(os.path.dirname(file_path), exist_ok=True)

# Read the CSV file
df = pd.read_csv(file_path)

# Define the new column order
new_column_order = [
    'Match_No', 'Team1', 'Team2', 'Toss_Winner', 'Toss_Decision',
    'Team1_Runs', 'Team1_Wickets', 'Team1_Overs', 'Team2_Runs', 'Team2_Wickets', 'Team2_Overs',
    'Winner', 'Is_Super_Over', 'Margin', 'WonBy', 'Player_of_Match',
    'Umpire1', 'Umpire2', 'Third_Umpire', 'Referee', 'Date', 'Time', 'Venue', 'Status',
    'Captain_Team1', 'Coach_Team1', 'Owner_Team1', 'Captain_Team2', 'Coach_Team2', 'Owner_Team2'
]

# Clean and standardize 'Is_Super_Over'
df['Is_Super_Over'] = df['Is_Super_Over'].astype(str)
df['Is_Super_Over'] = df['Is_Super_Over'].map(
    lambda x: "No" if x.lower() == "false" else 
              "Yes" if x.lower() == "true" else 
              "NA" if pd.isna(x) or x.strip() == "" else x
)

# Apply logic if Super Over happened
df.loc[df['Is_Super_Over'] == 'Yes', 'Margin'] = 'Super Over'
df.loc[df['Is_Super_Over'] == 'Yes', 'WonBy'] = 'Decided in Super Over'

# Fill other empty cells with "NA"
df = df.fillna("NA")

# Reorder columns
existing_columns = {}
for col in new_column_order:
    if col in df.columns:
        existing_columns[col] = col
    else:
        print(f"Warning: Column '{col}' not found in the dataframe.")

ordered_existing_columns = list(existing_columns.keys())
df_reordered = df[ordered_existing_columns]

# Save the cleaned and updated data
df_reordered.to_csv(output_path, index=False)

print(f"Data has been reorganized and saved to {output_path}")
# Out:
# Data has been reorganized and saved to Ipl Matches (2025)/Final2025IPL.csv
# C:\Users\ajmal\AppData\Local\Temp\ipykernel_12076\1532504293.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Super Over' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Is_Super_Over'] == 'Yes', 'Margin'] = 'Super Over'
